# %%
from collections import Counter
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_rows', 30)

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from statistic import Statistic
from utils import UtilsKy
from analyzer import HelperAnalyzer, AnalyzerPrediction
from reputation import Reputation

# %%
from datetime import datetime, timedelta

# %%
# for autoreload modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# kyw3
path_data = '/mnt/files/workdata/work/merchants/merchant_33_kyw3_2020-06-05/02_pure_data/'
df = pd.read_csv(path_data + 'kyw3_for_resolve.csv', dtype=str)

# %%
df.head()
# Out:
#             order_id    type status                 date            processed  \
# 0  49219577955111383  charge  false  2019-11-20 09:39:36  2019-11-20 09:39:41
# 1  49221760925063337  charge  false  2019-11-20 12:01:43  2019-11-20 12:01:50
# 2  49224688788195598  charge  false  2019-11-20 15:12:20  2019-11-20 15:12:24
# 3  49224696921328680  charge  false  2019-11-20 15:12:52  2019-11-20 15:12:55
# 4  49224839756465248  charge  false  2019-11-20 15:22:10  2019-11-20 15:22:13
#
#    amount currency        card_holder                   email          phone  \
# 0    1.00      USD    Gabriele Markes     gabriele@markes.com  5556789364528
# 1   25.00      USD       Malia Gusman  560100032720@4null.com     8086510074
# 2   21.18      USD      Stephen Gordy  560536900411@4null.com     7406005440
# 3  200.00      USD  Nicholas Saephanh  560131190505@4null.com     5102929855
# 4    2.38      USD   Thiago Fernandes  550322045766@4null.com    21994891341
#
# ...

# %%
reputation = Reputation(df)

# %%
df_reputation = reputation.create_reputation_factors()

# %%
df_reputation.shape
# Out:
# (574426, 7)

# %%
Statistic.get_table(df, 'id')
# Out:
# Counter({'547087******1680_2022-04': 1,
#          '517148******7320_2023-04': 1,
#          '546540******9404_2023-07': 4,
#          '510805******1186_2023-03': 1,
#          '544731******7316_2026-07': 7,
#          '524038******2438_2019-11': 9,
#          '551791******0023_2023-08': 39,
#          '517805******1411_2020-10': 2,
#          '517805******8864_2024-02': 107,
#          '517805******1498_2024-04': 36,
#          '516292******8849_2027-05': 27,
#          '510805******8751_2023-09': 3,
#          '552433******9968_2024-04': 5,
#          '531262******0403_2023-03': 5,
#          '523222******7629_2021-06': 5,
#          '517279******7598_2021-11': 196,
#          '546540******2973_2023-07': 40,
#          '527515******8586_2023-08': 1,
#          '517805******8932_2022-11': 21,
#          '542418******9612_2023-07': 1,
#          '526225******0684_2023-04': 38,
#          '516014******3041_2022-01': 1,
#          '531260******6333_2019-12': 6,
# ...

# %%
id = '516292******8849_2027-05'

# %%
df_sub = df[df.id == id]
df_sub.shape
# Out:
# (27, 24)

# %%
col_names = ['id', 'date', 'date_cb_only', 'status']
df_sub.loc[:, col_names  ]
# Out:
#                               id                 date date_cb_only status
# 10      516292******8849_2027-05  2019-11-20 15:43:59   2019-11-20  false
# 11      516292******8849_2027-05  2019-11-20 15:44:38   2019-11-20  false
# 13      516292******8849_2027-05  2019-11-20 15:45:23   2019-11-20  false
# 14      516292******8849_2027-05  2019-11-20 15:45:45   2019-11-20  false
# 10678   516292******8849_2027-05  2019-11-26 15:10:05   2019-11-26  false
# 10679   516292******8849_2027-05  2019-11-26 15:10:34   2019-11-26  false
# 10853   516292******8849_2027-05  2019-11-26 19:16:18   2019-11-26  false
# 10913   516292******8849_2027-05  2019-11-26 20:14:13   2019-11-26  false
# 19738   516292******8849_2027-05  2019-11-30 13:54:07   2019-11-30  false
# 44742   516292******8849_2027-05  2019-12-10 19:41:53   2019-12-10  false
# 67377   516292******8849_2027-05  2019-12-16 16:08:32   2019-12-16  false
# 90021   516292******8849_2027-05  2019-12-21 19:47:27   2019-12-21  false
# ...

# %%
ids = list(df_sub.index)
ids
df_reputation.iloc[ids,:]
# Out:
#         line_num  n_previous  n_grey  n_bads  is_quick  is_first  n_in_day
# 112952        10           0       0       0         0         1         0
# 112953        11           1       0       0         1         0         1
# 112954        13           2       0       0         1         0         2
# 112955        14           3       0       0         1         0         3
# 112956     10678           4       0       0         0         0         0
# 112957     10679           5       0       0         1         0         1
# 112958     10853           6       0       0         0         0         2
# 112959     10913           7       0       0         1         0         3
# 112960     19738           8       0       0         0         0         0
# 112961     44742           9       0       0         0         0         0
# 112962     67377          10       0       0         0         0         0
# ...
